# %%
print("Hello Ragesh G R")
# Out:
# Hello Ragesh G R

# %%
print("Welcome to AI and ML learning journey")
# Out:
# Welcome to AI and ML learning journey

# %%
print("I will become an AI-ML engineer in 2027")
# Out:
# I will become an AI-ML engineer in 2027

# %%
favorite_movie = "Cars"
favorite_game = "Battlefield games"
favorite_food = "Biriyani"

print(favorite_movie)
print(favorite_game)
print(favorite_food)
# Out:
# Cars
# Battlefield games
# Biriyani

# %%
name = "Shiva"
age = 17
height = 4.9
student = True

# %%
name = input("What is your name?")
city = input("What is your city?")
favorite_movie = input("What is your favorite movie?")

print("Your name is: ", name)
print("Your city is: ", city)
print("Your favorite movie is: ", favorite_movie)
# Out:
# Your name is:  ragesh
# Your city is:  mandya
# Your favorite movie is:  kgf

# %% [markdown]
# <h1>Today's project</h1>

# %%
title = "*** Student Profile Generator ***"
name = input("Enter your name: ")
age = input("Enter your age: ")
college = input("Enter your college name: ")
branch = input("Enter your branch: ")
favorite_programming_language = input("Enter your favorite programming language: ")

print(title)
print("Name:", name)
print("Age:", age)
print("College:", college)
print("Branch:", branch)
print("Favorite Programming Language:", favorite_programming_language)
# Out:
# *** Student Profile Generator ***
# Name: ragesh
# Age: 21
# College: mitm
# Branch: ai
# Favorite Programming Language: python

# %% [markdown]
# <h3>Assessments</h3>

# %%
print("Hi I am Ragesh G R")

city = "Mandya"
print("My city is: ", city)

age = 21
print("Myage is: ", age)
# Out:
# Hi I am Ragesh G R
# My city is:  Mandya
# Myage is:  21

# %%
favorite_game = "Free Fire Max"
favorite_movie = "Cars"
favorite_company = "My own company"

print("My favorite game is: ", favorite_game)
print("My favorite movie is: ", favorite_movie)
print("My favorite company is: ", favorite_company)

favorite_company = "Google"
print("My favorite company is: ", favorite_company)
# Out:
# My favorite game is:  Free Fire Max
# My favorite movie is:  Cars
# My favorite company is:  My own company
# My favorite company is:  Google

# %%
print("Game Profile")
name = input("Enter your name: ")
favorite_game  = input("Enter your favorite game: ")
rankInGame = input("Enter your rank in the game: ")
country = input("Enter your country: ")

print("Hello", name)
print("Your favorite game:", favorite_game)
print("Your rank in the game:", rankInGame)
print("You are from:", country)
# Out:
# Game Profile
# Hello ragesh
# Your favorite game: free fire
# Your rank in the game: master
# You are from: india

# %% [markdown]
# <h1>Library Member Registration System</h1>

# %%
user = input("Enter your name: ")
use_age = input("Enter your age: ")
book_category = input("Enter your favorite book category: ")
membership = input("Enter your membership type: ")

print("Hi", user)
print("Your age:", use_age)
print("Your favorite book category:", book_category)
print("Your membership type:", membership)
# Out:
# Hi ragesh
# Your age: 21
# Your favorite book category: action
# Your membership type: gold
