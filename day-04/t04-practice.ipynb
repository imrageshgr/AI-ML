# %%
for i in range(5):
    print("Hello, Good morning!") #five times printed
# Out:
# Hello, Good morning!
# Hello, Good morning!
# Hello, Good morning!
# Hello, Good morning!
# Hello, Good morning!

# %%
for i in range(3):
    print(i) # output: 0, 1, 2
# Out:
# 0
# 1
# 2

# %%
for i in range(1, 10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
count = 1
while count < 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(11):
    if i % 2 != 0:
        print("Odd number:", i)
    else:
        print("Even number:", i)
# Out:
# Even number: 0
# Odd number: 1
# Even number: 2
# Odd number: 3
# Even number: 4
# Odd number: 5
# Even number: 6
# Odd number: 7
# Even number: 8
# Odd number: 9
# Even number: 10
